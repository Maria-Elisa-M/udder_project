# %%
#
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv(r"kick_offs\kick_offs2.csv", sep = ";")
df.columns = [col.replace(" ", "_").lower().replace("-", "") for col in df.columns]

# %%
df
# Out:
#      animal_number  avg._daily_kickoff_milkings_last_7d  \
# 0              254                                 0.00
# 1              453                                 0.00
# 2              454                                 0.00
# 3              497                                 0.00
# 4              571                                 0.43
# ..             ...                                  ...
# 601           1791                                 0.00
# 602           1792                                 0.00
# 603           1793                                 0.00
# 604           1794                                 0.00
# 605          13101                                 0.00
#
#      lf_avg._daily_kickoff_milkings_last_7d  \
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                      0.14
# ...

# %%
ko = df[~np.isnan(df.total_kickoffs_last_7d)].total_kickoffs_last_7d

# %%
plt.hist(ko)
# Out:
# (array([44.,  6.,  4.,  2.,  0.,  2.,  1.,  0.,  1.,  1.]),
#  array([ 1. ,  2.2,  3.4,  4.6,  5.8,  7. ,  8.2,  9.4, 10.6, 11.8, 13. ]),
#  <BarContainer object of 10 artists>)
