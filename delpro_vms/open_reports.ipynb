# %%
#
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import os
import seaborn as sns
from datetime import datetime, timedelta

# %%
# filter records only on current lactation
df = pd.read_csv(r"more_reports\milking_7days.csv", sep = ";")
df.columns = [col.replace(" ", "_").lower().replace("-", "") for col in df.columns]
df
# Out:
#       animal_number        date incomplete  incomplete_milkings kickoff_lf  \
# 0               897  11/15/2023        All                    1  Unchecked
# 1              1489  11/10/2023        NaN                    0  Unchecked
# 2              1472  11/15/2023        NaN                    0  Unchecked
# 3              1472  11/10/2023        NaN                    0  Unchecked
# 4              1401  11/10/2023     RF, RR                    1  Unchecked
# ...             ...         ...        ...                  ...        ...
# 5171           1236  11/10/2023        NaN                    0  Unchecked
# 5172           1380  11/10/2023        NaN                    0  Unchecked
# 5173           1476  11/10/2023        NaN                    0  Unchecked
# 5174           1225  11/10/2023        NaN                    0  Unchecked
# 5175           1447  11/10/2023        NaN                    0  Unchecked
#
#      kickoff_lr kickoff_rf kickoff_rr  incomplete_milkings.1  \
# 0     Unchecked  Unchecked  Unchecked                      1
# 1     Unchecked  Unchecked  Unchecked                      0
# 2     Unchecked  Unchecked  Unchecked                      0
# 3       Checked  Unchecked  Unchecked                      0
# 4     Unchecked  Unchecked  Unchecked                      1
# ...         ...        ...        ...                    ...
# 5171  Unchecked  Unchecked  Unchecked                      0
# 5172  Unchecked  Unchecked  Unchecked                      0
# 5173  Unchecked  Unchecked  Unchecked                      0
# 5174  Unchecked  Unchecked  Unchecked                      0
# 5175  Unchecked  Unchecked  Unchecked                      0
#
#       occ(*1000_cells/ml)  ...  milk_duration_(mm:ss)  lactation_number  \
# 0                     NaN  ...                  03:19                 4
# 1                     NaN  ...                  03:58                 1
# 2                     NaN  ...                  10:48                 1
# 3                     NaN  ...                  11:19                 1
# 4                     8.0  ...                  05:49                 1
# ...                   ...  ...                    ...               ...
# 5171                  8.0  ...                  08:21                 2
# 5172                  NaN  ...                  04:44                 1
# 5173                 14.0  ...                  07:08                 1
# 5174                114.0  ...                  05:24                 2
# 5175                  NaN  ...                  06:29                 1
#
#       position  teats_not_found           begin_time  end_time  mean_flow_lf  \
# 0            0              All   11/15/2023 4:05 AM   4:08 AM          0.00
# 1            0              All   11/10/2023 5:08 PM   5:12 PM          0.00
# 2            0       LF, LR, RR   11/15/2023 3:07 AM   3:17 AM          0.30
# 3            0       LF, RF, RR   11/10/2023 2:32 PM   2:43 PM          0.00
# 4            0           RF, RR   11/10/2023 1:54 PM   2:00 PM          1.92
# ...        ...              ...                  ...       ...           ...
# 5171         0              NaN  11/10/2023 12:09 AM  12:17 AM          0.84
# 5172         0              NaN  11/10/2023 12:12 AM  12:17 AM          1.50
# 5173         0              NaN  11/10/2023 12:07 AM  12:14 AM          0.78
# 5174         0              NaN  11/10/2023 12:08 AM  12:13 AM          1.92
# 5175         0              NaN  11/10/2023 12:04 AM  12:11 AM          0.96
#
#       mean_flow_lr  mean_flow_rf  mean_flow_rr
# 0             0.00          0.00          0.00
# 1             0.00          0.00          0.00
# 2             0.24          0.60          0.24
# 3             0.30          0.30          0.00
# 4             1.38          0.00          0.00
# ...            ...           ...           ...
# 5171          0.84          1.14          0.84
# 5172          1.62          1.38          1.26
# 5173          0.60          0.66          0.54
# 5174          1.38          1.98           NaN
# 5175          0.72          0.72          0.66
#
# [5176 rows x 36 columns]

# %%
# filter records only on current lactation
df = pd.read_csv(r"more_reports\one_year_milk.csv", sep = ";")
df.columns = [col.replace(" ", "_").lower().replace("-", "") for col in df.columns]
df
# Out:
#         animal_number        date  total_yield daily_avg._duration_(mm:ss)  \
# 0                1102  11/17/2022        30.41                       07:00
# 1                1102  11/17/2022        30.41                       07:00
# 2                1146  11/17/2022        35.69                       06:13
# 3                1146  11/17/2022        35.69                       06:13
# 4                1094  11/17/2022        82.33                       06:04
# ...               ...         ...          ...                         ...
# 199287           1177  11/17/2023        31.52                       14:22
# 199288           1164  11/17/2023        22.76                       07:04
# 199289           1246  11/17/2023        13.79                       06:28
# 199290            902  11/17/2023        21.77                       09:09
# 199291           1360  11/17/2023        13.58                       06:48
#
#         avg._daily_yield_previous_7d  days_in_milk
# 0                              46.04           203
# 1                              46.04           203
# 2                              47.75           144
# 3                              47.75           144
# 4                              61.54            59
# ...                              ...           ...
# 199287                         49.95            20
# 199288                         59.16            24
# 199289                         45.21           249
# 199290                         48.09            66
# 199291                         35.56           281
#
# [199292 rows x 6 columns]

# %%
# filter records only on current lactation
df = pd.read_csv(r"more_reports\milk_perf7days.csv", sep = ";")
df.columns = [col.replace(" ", "_").lower().replace("-", "") for col in df.columns]
df
# Out:
#      animal_number       group_name  lactation_number  days_in_milk  \
# 0             1058    VMS 1&2 group                 2           445
# 1              948    VMS 1&2 group                 3           437
# 2             1320  VMS 3 & 4 Group                 1           414
# 3             1200    VMS 1&2 group                 2           356
# 4             1329  VMS 3 & 4 Group                 1           355
# ..             ...              ...               ...           ...
# 235           1184  VMS 3 & 4 Group                 3             4
# 236           1511  VMS 3 & 4 Group                 1             3
# 237           1484      Calving pen                 1             1
# 238           1314  VMS 3 & 4 Group                 2             1
# 239            855  VMS 3 & 4 Group                 5             0
#
#      avg_daily_yield_last_7_days  avg_daily_milkings_last_7_days  \
# 0                          39.88                            2.57
# 1                          34.01                            2.43
# 2                          32.60                            1.57
# 3                          34.33                            2.43
# 4                          31.39                            2.29
# ..                           ...                             ...
# 235                        22.61                            1.00
# 236                         9.77                            0.71
# 237                         6.01                            0.29
# 238                         4.89                            0.14
# 239                         0.00                            0.00
#
#     max_milking_interval_last_7_days  avg_yield_per_milking_last_7_days  \
# 0                              13:50                              15.51
# 1                              18:28                              14.88
# 2                              21:54                              20.75
# 3                              13:55                              14.14
# 4                              15:49                              13.73
# ..                               ...                                ...
# 235                            13:26                              12.92
# 236                            14:43                               5.86
# 237                            10:39                               3.01
# 238                            00:00                               4.89
# 239                            00:00                               0.00
#
#     avg_milking_duration_last_7_days  avg_flow_last_7_days  \
# 0                              06:57                  4.24
# 1                              06:05                  4.83
# 2                              07:03                  4.72
# 3                              06:56                  3.94
# 4                              05:44                  4.62
# ..                               ...                   ...
# 235                            05:10                  6.58
# 236                            06:29                  3.41
# 237                            05:09                  2.70
# 238                            04:40                  3.54
# 239                            00:00                  0.00
#
#      avg_daily_harvesting_flow_last_7_days  \
# 0                                     2.23
# 1                                     2.46
# 2                                     2.96
# 3                                     2.04
# 4                                     2.41
# ..                                     ...
# 235                                   2.51
# 236                                   0.92
# 237                                   0.60
# 238                                   1.22
# 239                                   0.00
#
#      avg_kick_offs_per_milking_last_7_days  \
# 0                                     0.06
# 1                                     0.00
# 2                                     0.00
# 3                                     0.00
# 4                                     0.00
# ..                                     ...
# 235                                   0.00
# 236                                   0.20
# 237                                   0.00
# 238                                   0.00
# 239                                   0.00
#
#      avg_incomplete_milkings_last_7_days  performance_index
# 0                                   0.00                100
# 1                                   0.00                100
# 2                                   0.00                100
# 3                                   0.00                100
# 4                                   0.14                100
# ..                                   ...                ...
# 235                                 0.00                100
# 236                                 0.00                100
# 237                                 0.00                100
# 238                                 0.00                100
# 239                                 0.00                  0
#
# [240 rows x 14 columns]

# %%
# peak flow
# incomplete milkings
# teats not found
