# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import seaborn as sns

# %%
df = pd.read_csv("milk_videos.csv")
df["time"] = [datetime.strptime(time, '%H:%M:%S') for time in df["time"]]
df = df.sort_values(by='time').drop_duplicates('cow')

# %%
len(df)
# Out:
# 151

# %%
plt.hist(df[~np.isnan(df.lactation_number)].lactation_number)
# Out:
# (array([54.,  0., 41.,  0., 28.,  0., 19.,  0.,  8.,  1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df[~np.isnan(df.lactation_number)].days_in_milk)
# Out:
# (array([32., 21., 20., 13., 15., 26., 14.,  5.,  3.,  2.]),
#  array([  2. ,  45.6,  89.2, 132.8, 176.4, 220. , 263.6, 307.2, 350.8,
#         394.4, 438. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df[~np.isnan(df.lactation_number)].latest_lifetime_daily_yield)
# Out:
# (array([19.,  8.,  7., 24.,  9., 16., 17., 18., 23., 10.]),
#  array([ 0.2 ,  5.91, 11.62, 17.33, 23.04, 28.75, 34.46, 40.17, 45.88,
#         51.59, 57.3 ]),
#  <BarContainer object of 10 artists>)

# %%
df["yield"]
# Out:
# 148    23.72
# 150    42.77
# 125    36.88
# 133    27.21
# 70     21.65
#        ...
# 53     39.18
# 21     47.84
# 46     26.52
# 27     36.42
# 50     45.39
# Name: yield, Length: 151, dtype: float64

# %%
plt.hist(df["yield"])
# Out:
# (array([ 2.,  7., 18., 22., 27., 31., 24., 14.,  5.,  1.]),
#  array([ 8.14 , 14.275, 20.41 , 26.545, 32.68 , 38.815, 44.95 , 51.085,
#         57.22 , 63.355, 69.49 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.yield_lf)
# Out:
# (array([ 3., 12., 30., 30., 35., 17., 11.,  2.,  1.,  1.]),
#  array([ 1.12 ,  3.129,  5.138,  7.147,  9.156, 11.165, 13.174, 15.183,
#         17.192, 19.201, 21.21 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.quarters_num)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,  20.,   0.,   0.,   0., 130.]),
#  array([2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
df.columns
# Out:
# Index(['cow', 'farmname', 'robotside', 'filename', 'date', 'time', 'size',
#        'begin_time', 'end_time', 'yield', 'device_name', 'conductivity_lf',
#        'conductivity_lr', 'conductivity_rf', 'conductivity_rr', 'mean_flow_lf',
#        'mean_flow_lr', 'mean_flow_rf', 'mean_flow_rr', 'yield_lf', 'yield_lr',
#        'yield_rf', 'yield_rr', 'occ(*1000_cells/ml)', 'peak_flow_lf',
#        'peak_flow_lr', 'peak_flow_rf', 'peak_flow_rr', 'interval',
#        'quarters_num', 'num_videos', 'birth_date', 'age_in_days',
#        'last_calving_date', 'days_in_milk', 'lactation_number',
#        'total_kick-offs_last_7d', 'peak_occ_current_lactation',
#        'latest_lifetime_daily_yield', 'total_lifetime_yield', 'type',
#        'avg._occ_last_9_milkings', 'avg._flow_last_7_days',
#        'avg._yield_per_milking_last_7d', 'total_yield_in_lactation',
#        'peak_yield', 'peak_yield_day', 'peak_occ_current_lactation.1'],
#       dtype='object')
