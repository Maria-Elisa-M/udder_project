# %%
# imports
import pandas as pd
import os
import numpy as np 
import json
import skimage as ski
import matplotlib.pyplot as plt
from skimage.measure import find_contours
from matplotlib import colors
from skimage import exposure
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

# %%
# data sources
label_path = r"C:\Users\marie\rep_codes\udder_project\udder_processing\validate_watershed\pred_labels"
image_path = r"C:\Users\marie\rep_codes\udder_project\udder_video\depth_images"
ws_path2 = r"C:\Users\marie\rep_codes\udder_project\udder_processing\validate_watershed\watershed_segments"
ws_path3 = r"C:\Users\marie\rep_codes\udder_project\udder_processing\validate_watershed\watershed_correspondence"
ws_path = r"C:\Users\marie\rep_codes\udder_project\udder_processing\validate_watershed\watershed_data\array"
segment_path = os.path.join(label_path, "segments")
keypoint_path = os.path.join(label_path, "keypoints")

color_dict = {'lf': "#666666", 'rf': '#999999', 'lb': '#BC1E40', 'rb': '#A32A44'}

# %%
image_name = "1335_20231117_121441_frame_329"
image_name2 = "1335_20231117_121441_frame_329"
kp_filepath = os.path.join(keypoint_path, f"{image_name}.txt")
sg_filepath = os.path.join(segment_path, f"{image_name}.txt")
ws_filepath = os.path.join(ws_path, f"{image_name}.npy")

img = ski.io.imread(os.path.join(image_path, image_name.split("_")[0], f"{image_name}.tif"))
img = exposure.equalize_hist(img, nbins=256, mask=None)
img_size = img.shape
with open(sg_filepath, "r") as f:
    udder_segment = np.array([float(point) for point in f.read().split(" ")][1:])
    udder_segment = udder_segment.reshape((int(len(udder_segment)//2),2))
with open(kp_filepath, "r") as f:
    data =  [float(point) for point in f.read().split(" ")]
    points = np.array(data[5:])
points = points.reshape((4,3))
points[:, 0] = points[:, 0] * img_size[1]
points[:, 1] = points[:, 1] * img_size[0]
udder_coords = np.array([[coord[0] * img_size[1], coord[1]* img_size[0]] for coord in udder_segment])
polygon2 = [[coord[1]* img_size[0], coord[0] * img_size[1]] for coord in udder_segment]
udder_mask = ski.draw.polygon2mask(img_size, polygon2)
masked_image = img.copy()
masked_image[udder_mask == 0] = 0
contour = find_contours(udder_mask)[0]
polygon = np.array([[coord[1], coord[0]] for coord in contour])

ws_mask = np.load(ws_filepath)
ws_mask2 = ws_mask[:, :, 0]*2+ ws_mask[:, :, 1]*4 + ws_mask[:, :, 2]*6
seg_contours = find_contours(ws_mask2)

cor_df = pd.read_csv(os.path.join(ws_path3, f"{image_name2}.csv"))
label_file = os.path.join(ws_path2, f"{image_name2}.npy")
labels = np.load(label_file)
labels_mask =labels.copy().astype("float")
cdic = cor_df.to_dict(orient = "index")[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2860\3876439306.py in ?()
#       3 kp_filepath = os.path.join(keypoint_path, f"{image_name}.txt")
#       4 sg_filepath = os.path.join(segment_path, f"{image_name}.txt")
#       5 ws_filepath = os.path.join(ws_path, f"{image_name}.npy")
#       6
# ----> 7 img = ski.io.imread(os.path.join(image_path, image_name.split("_")[0], f"{image_name}.tif"))
#       8 img = exposure.equalize_hist(img, nbins=256, mask=None)
#       9 img_size = img.shape
#      10 with open(sg_filepath, "r") as f:
#
# ~\miniconda3\Lib\site-packages\skimage\io\_io.py in ?(fname, as_gray, plugin, **plugin_args)
#      56         if fname.lower().endswith(('.tiff', '.tif')):
#      57             plugin = 'tifffile'
#      58
#      59     with file_or_url_context(fname) as fname:
# ---> 60         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      61
#      62     if not hasattr(img, 'ndim'):
#      63         return img
#
# ~\miniconda3\Lib\site-packages\skimage\io\manage_plugins.py in ?(kind, *args, **kwargs)
#     213             func = [f for (p, f) in plugin_funcs if p == plugin][0]
#     214         except IndexError:
#     215             raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
#     216
# --> 217     return func(*args, **kwargs)
#
# ~\miniconda3\Lib\site-packages\skimage\io\_plugins\tifffile_plugin.py in ?(fname, **kwargs)
#      70     """
#      71     if 'img_num' in kwargs:
#      72         kwargs['key'] = kwargs.pop('img_num')
#      73
# ---> 74     return tifffile_imread(fname, **kwargs)
#
# ~\miniconda3\Lib\site-packages\tifffile\tifffile.py in ?(files, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1058
#    1059         if isinstance(files, str) or not isinstance(
#    1060             files, collections.abc.Sequence
#    1061         ):
# -> 1062             with TiffFile(
#    1063                 files,
#    1064                 mode=mode,
#    1065                 name=name,
#
# ~\miniconda3\Lib\site-packages\tifffile\tifffile.py in ?(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    3989
#    3990         if mode not in (None, 'r', 'r+', 'rb', 'r+b'):
#    3991             raise ValueError(f'invalid mode {mode!r}')
#    3992
# -> 3993         fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    3994         self._fh = fh
#    3995         self._multifile = True if _multifile is None else bool(_multifile)
#    3996         self._files = {fh.name: self}
#
# ~\miniconda3\Lib\site-packages\tifffile\tifffile.py in ?(self, file, mode, name, offset, size)
#   13925         self._offset = -1 if offset is None else offset
#   13926         self._size = -1 if size is None else size
#   13927         self._close = True
#   13928         self._lock = NullContext()
# > 13929         self.open()
#   13930         assert self._fh is not None
#
# ~\miniconda3\Lib\site-packages\tifffile\tifffile.py in ?(self)
#   13940         if isinstance(self._file, str):
#   13941             # file name
#   13942             self._file = os.path.realpath(self._file)
#   13943             self._dir, self._name = os.path.split(self._file)
# > 13944             self._fh = open(self._file, self._mode)  # type: ignore
#   13945             self._close = True
#   13946             if self._offset < 0:
#   13947                 self._offset = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\marie\\rep_codes\\udder_project\\udder_video\\depth_images\\1335\\1335_20231117_121441_frame_329.tif'

# %%
cmap = colors.ListedColormap(["black", "darkgray",  "dimgray",  "silver", "white"])
fig, axs = plt.subplots()
axs.imshow(img, cmap = "gray")
axs.imshow(udder_mask, alpha = 0, cmap = cmap)
axs.plot(polygon[:, 0], polygon[:, 1], ".", color = "white", markersize= 3)
# axs.plot(points[2:, 0], points[2:, 1]-10, ".", color = "#C00000",  markersize= 10)
# axs.plot(points[:2, 0], points[:2, 1], ".", color = "black",  markersize= 10)
# axs.imshow(np.floor(ws_mask2), cmap = cmap, alpha = 0.3)
for contour in seg_contours:
    axs.plot(contour[:, 1], contour[:, 0], ".", color = "white", markersize= 3)

for k, val in cdic.items():
    colorname = color_dict[k]
    mask_q = labels_mask.copy()
    mask_q[np.where(mask_q!= val)] = np.nan
    mask_q[np.where(mask_q== val)] = 1
    axs.imshow(mask_q, cmap = ListedColormap([colorname]) , alpha=0.5)
axs.axis('off')
fig.savefig("ws_good.png", bbox_inches='tight', pad_inches=0)

# %%
image_name = "1295_20231117_130928_frame_334"
image_name2 = "1295_20231117_130928_frame_334"
kp_filepath = os.path.join(keypoint_path, f"{image_name}.txt")
sg_filepath = os.path.join(segment_path, f"{image_name}.txt")
ws_filepath = os.path.join(ws_path, f"{image_name}.npy")

img = ski.io.imread(os.path.join(image_path, image_name.split("_")[0], f"{image_name}.tif"))
img = exposure.equalize_hist(img, nbins=256, mask=None)
img_size = img.shape
with open(sg_filepath, "r") as f:
    udder_segment = np.array([float(point) for point in f.read().split(" ")][1:])
    udder_segment = udder_segment.reshape((int(len(udder_segment)//2),2))
with open(kp_filepath, "r") as f:
    data =  [float(point) for point in f.read().split(" ")]
    points = np.array(data[5:])
points = points.reshape((4,3))
points[:, 0] = points[:, 0] * img_size[1]
points[:, 1] = points[:, 1] * img_size[0]
udder_coords = np.array([[coord[0] * img_size[1], coord[1]* img_size[0]] for coord in udder_segment])
polygon2 = [[coord[1]* img_size[0], coord[0] * img_size[1]] for coord in udder_segment]
udder_mask = ski.draw.polygon2mask(img_size, polygon2)
masked_image = img.copy()
masked_image[udder_mask == 0] = 0
contour = find_contours(udder_mask)[0]
polygon = np.array([[coord[1], coord[0]] for coord in contour])

ws_mask = np.load(ws_filepath)
ws_mask2 = ws_mask[:, :, 0]*2+ ws_mask[:, :, 1]*4 + ws_mask[:, :, 2]*6
seg_contours = find_contours(ws_mask2)

cor_df = pd.read_csv(os.path.join(ws_path3, f"{image_name2}.csv"))
label_file = os.path.join(ws_path2, f"{image_name2}.npy")
labels = np.load(label_file)
labels_mask =labels.copy().astype("float")
cdic = cor_df.to_dict(orient = "index")[0]

# %%
cmap = colors.ListedColormap(["black", "darkgray",  "dimgray",  "silver", "white"])
fig, axs = plt.subplots()
axs.imshow(img, cmap = "gray")
axs.imshow(udder_mask, alpha = 0, cmap = cmap)
axs.plot(polygon[:, 0], polygon[:, 1], ".", color = "white", markersize= 3)
# axs.plot(points[2:, 0], points[2:, 1]-10, ".", color = "#C00000",  markersize= 10)
# axs.plot(points[:2, 0], points[:2, 1], ".", color = "black",  markersize= 10)
# axs.imshow(np.floor(ws_mask2), cmap = cmap, alpha = 0.3)
for contour in seg_contours:
    axs.plot(contour[:, 1], contour[:, 0], ".", color = "white", markersize= 3)

for k, val in cdic.items():
    colorname = color_dict[k]
    mask_q = labels_mask.copy()
    mask_q[np.where(mask_q!= val)] = np.nan
    mask_q[np.where(mask_q== val)] = 1
    axs.imshow(mask_q, cmap = ListedColormap([colorname]) , alpha=0.5)
axs.axis('off')
fig.savefig("ws_bad.png", bbox_inches='tight', pad_inches=0)
