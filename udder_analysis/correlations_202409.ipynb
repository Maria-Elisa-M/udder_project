# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
plt.rcParams.update({'font.size': 14})

# %%
dirpath = os.getcwd()
features_path = r"C:\Users\marie\rep_codes\udder_project\udder_processing\features_dict\gmfeature_table.csv"
data_path = r"C:\Users\marie\rep_codes\udder_project\delpro_vms\data_out"
plot_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),r"adsa\examples")

# %% [markdown]
# # conductivity

# %%
fdf = pd.read_csv(os.path.join(data_path, 'mcond_integrated.csv'))
ddf = pd.read_csv(features_path)

merged = ddf.merge(fdf, on = "cow", how= "left")
v = "lb_vol"
u = "conductivity_lf_7d"
selected = merged[[v, u ]].dropna(axis=0) 
selected =selected[selected[u] > 0]
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], "*b")
print(res)
# Out:
# PearsonRResult(statistic=0.0948275268862556, pvalue=0.3244173718216994)

# %% [markdown]
# # Yield

# %%
fdf = pd.read_csv(os.path.join(data_path, 'myield_integrated.csv'))
ddf = pd.read_csv(features_path)
merged = ddf.merge(fdf, on = "cow", how= "left")

# %%
v = "udder_sarea"
u = "vyield_udder_cl"
print(v+"_vs_"+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_area"
u = "vyield_udder_cl"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_vol"
u = "vyield_udder_cl"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_peri"
u = "vyield_udder_cl"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "lf_peri"
u = "vyield_lf_cl"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "rf_vol"
u = "vyield_rf_cl"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
# Out:
# udder_sarea_vs_vyield_udder_cl
# PearsonRResult(statistic=0.43060120187030126, pvalue=3.513745304222223e-07)
#
#
# udder_area vs vyield_udder_cl
# PearsonRResult(statistic=0.536591928743746, pvalue=3.94446710534541e-11)
#
#
# udder_vol vs vyield_udder_cl
# PearsonRResult(statistic=0.40151252331576237, pvalue=2.8899486254226895e-06)
#
#
# udder_peri vs vyield_udder_cl
# PearsonRResult(statistic=0.5499770109328689, pvalue=1.017973911933616e-11)
#
#
# lf_peri vs vyield_lf_cl
# PearsonRResult(statistic=0.4004989298777545, pvalue=3.692879618247844e-06)
#
#
# rf_vol vs vyield_rf_cl
# PearsonRResult(statistic=0.13223645883342278, pvalue=0.1482164981964234)

# %%
fdf = pd.read_csv(os.path.join(data_path, 'myield_integrated.csv'))
ddf = pd.read_csv(features_path)
merged = ddf.merge(fdf, on = "cow", how= "left")

v = "udder_sarea"
u = "vyield_udder_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")

plt.ylabel("Average visit yield current lact. (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.43060120187030126, pvalue=3.513745304222223e-07)

# %%
v = "front_eu"
u = "vyield_udder_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Front Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.09436495365828129, pvalue=0.2912966995496543)

# %%
v = "back_eu"
u = "vyield_udder_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.21213481995611083, pvalue=0.020016607024966836)

# %%
v = "lb_len"
u = "vyield_lb_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Left rear teat length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.42464891503423763, pvalue=1.3387845758938445e-06)

# %%
v = "rb_len"
u = "vyield_rb_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Right rear length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.21061226162963542, pvalue=0.02206650744076355)

# %%
v = "rf_len"
u = "dyield_rf_dim_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Right rear length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.05688586337862441, pvalue=0.5388854404562922)

# %%
u = "vyield_udder_7d"
v = ['lf_angle', 'rf_angle', 'lb_angle', 'rb_angle']
merged["angle"]= merged[v[0]] + merged[v[1]] + merged[v[2]] + merged[v[3]]
selected = merged[[u, "angle"]].dropna(axis=0) 
res = stats.pearsonr(selected[u], selected["angle"])
plt.plot(selected[u], selected["angle"], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=-0.129916314436551, pvalue=0.2070947216787635)

# %% [markdown]
# # peak flow

# %%
fdf = pd.read_csv(os.path.join(data_path, 'mpf_integrated.csv'))
ddf = pd.read_csv(features_path)
merged = ddf.merge(fdf, on = "cow", how= "left")

# %%
v = "lb_len"
u = "peak_flow_lb_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.14596689429573972, pvalue=0.11319377342816972)

# %%
v = "rb_len"
u = "peak_flow_rb_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=-0.08333771158698654, pvalue=0.369609854870266)

# %%
v = "rf_exc"
u = "peak_flow_rf_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.08853926514473659, pvalue=0.32615690101309497)

# %% [markdown]
# # Interval

# %%
dirpath = os.getcwd()
vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
merged = ddf.merge(vms_df, on ="cow", how= "left")

# %%
from operator import mul

def time_tomin(my_time):
    factors = (60, 1, 1/60)
    t1 = sum(i*j for i, j in zip(map(int, my_time.split(':')), factors))
    t2 = sum(map(mul, map(int, my_time.split(':')), factors))
    return t2

# %%
v = "udder_vol"
u = "interval"
z = "lactation_number"
selected = merged[[v, u, z]].dropna(axis=0).reset_index()
selected[u] = [time_tomin(selected.loc[i, u]) for i in range(len(selected))] 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[u], selected[v],".", color = "gray")
plt.ylabel("Udder volume (L)")
plt.xlabel("Interval to last visit (min)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.24335059276669657, pvalue=0.005641412156026013)

# %%
u = "udder_sarea"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)
# Out:
# PearsonRResult(statistic=0.38056415267463584, pvalue=7.953357142982856e-06)

# %%
u = "lb_len"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)
# Out:
# PearsonRResult(statistic=0.3944564973191206, pvalue=6.346249021084059e-06)

# %%
v = "udder_sarea"
u = "vyield_udder_7d"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(x,y, "*b")
print(res)
# Out:
# PearsonRResult(statistic=0.4483180884897785, pvalue=1.2528356824704467e-07)

# %%
dirpath = os.getcwd()
vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
merged = ddf.merge(vms_df, on ="cow", how= "left")

# %%
v = "udder_sarea"
u = "peak_yield"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(x,y, "*b")
print(res)
# Out:
# PearsonRResult(statistic=0.4130883475926361, pvalue=7.723219396997628e-05)

# %%
merged.columns
# Out:
# Index(['cow', 'udder_vol', 'lf_vol', 'rf_vol', 'lb_vol', 'rb_vol',
#        'udder_sarea', 'lf_sarea', 'rf_sarea', 'lb_sarea', 'rb_sarea',
#        'lf_angle', 'rf_angle', 'lb_angle', 'rb_angle', 'front_eu', 'back_eu',
#        'right_eu', 'left_eu', 'front_gd', 'back_gd', 'right_gd', 'left_gd',
#        'udder_peri', 'udder_area', 'udder_circ', 'udder_exc', 'lf_peri',
#        'lf_area', 'lf_circ', 'lf_exc', 'rf_peri', 'rf_area', 'rf_circ',
#        'rf_exc', 'lb_peri', 'lb_area', 'lb_circ', 'lb_exc', 'rb_peri',
#        'rb_area', 'rb_circ', 'rb_exc', 'lf_len', 'rf_len', 'lb_len', 'rb_len',
#        'farmname', 'robotside', 'filename', 'directory', 'date', 'time',
#        'size', 'computer', 'begin_time', 'end_time', 'yield', 'device_name',
#        'conductivity_lf', 'conductivity_lr', 'conductivity_rf',
#        'conductivity_rr', 'mean_flow_lf', 'mean_flow_lr', 'mean_flow_rf',
#        'mean_flow_rr', 'yield_lf', 'yield_lr', 'yield_rf', 'yield_rr',
#        'occ(*1000_cells/ml)', 'peak_flow_lf', 'peak_flow_lr', 'peak_flow_rf',
#        'peak_flow_rr', 'interval', 'quarters_num', 'num_videos', 'birth_date',
#        'age_in_days', 'last_calving_date', 'days_in_milk', 'lactation_number',
#        'total_kick-offs_last_7d', 'peak_occ_current_lactation',
#        'latest_lifetime_daily_yield', 'total_lifetime_yield', 'type',
#        'avg._occ_last_9_milkings', 'avg._flow_last_7_days',
#        'avg._yield_per_milking_last_7d', 'total_yield_in_lactation',
#        'peak_yield', 'peak_yield_day', 'peak_occ_current_lactation.1'],
#       dtype='object')
