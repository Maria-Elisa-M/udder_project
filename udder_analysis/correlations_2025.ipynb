# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
plt.rcParams.update({'font.size': 14})

# %%
dirpath = os.getcwd()
features_path = r"C:\Users\marie\rep_codes\udder_project\udder_processing\features_dict\gmfeature_table.csv"
data_path = r"C:\Users\marie\rep_codes\udder_project\delpro_vms\data"
plot_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),r"adsa\examples")

# %%
merged = pd.read_csv(os.path.join("long_format_df", "lactation_features.csv"))
merged.columns
# Out:
# Index(['cow', 'vol_udder', 'vol_lf', 'vol_rf', 'vol_lb', 'vol_rb',
#        'sarea_udder', 'sarea_lf', 'sarea_rf', 'sarea_lb', 'sarea_rb',
#        'angle_lf', 'angle_rf', 'angle_lb', 'angle_rb', 'eu_front', 'eu_back',
#        'eu_right', 'eu_left', 'gd_front', 'gd_back', 'gd_right', 'gd_left',
#        'peri_udder', 'area_udder', 'circ_udder', 'exc_udder', 'peri_lf',
#        'area_lf', 'circ_lf', 'exc_lf', 'peri_rf', 'area_rf', 'circ_rf',
#        'exc_rf', 'peri_lb', 'area_lb', 'circ_lb', 'exc_lb', 'peri_rb',
#        'area_rb', 'circ_rb', 'exc_rb', 'len_lf', 'len_rf', 'len_lb', 'len_rb',
#        'animal_number', 'min_date', 'max_date', 'count_date', 'min_dim',
#        'max_dim', 'milk_flow_duration_mean', 'yield_visit_mean',
#        'yield_lf_visit_mean', 'yield_lr_visit_mean', 'yield_rr_visit_mean',
#        'yield_rf_visit_mean', 'peak_flow_rf_mean', 'peak_flow_lf_mean',
#        'peak_flow_rr_mean', 'peak_flow_lr_mean', 'notmilk_visit_duration_mean',
#        'interval_sec_mean', 'kickoff_lf_sum', 'kickoff_lr_sum',
#        'kickoff_rf_sum', 'kickoff_rr_sum', 'kickoff_front_sum',
#        'kickoff_back_sum', 'kickoff_any_sum', 'total_yield', 'total_visits',
#        'kickoff_lf_perc', 'kickoff_lr_perc', 'kickoff_rf_perc',
#        'kickoff_rr_perc', 'kickoff_front_perc', 'kickoff_back_perc',
#        'kickoff_any_perc', 'yield_lf_visit_sum', 'yield_lr_visit_sum',
#        'yield_rr_visit_sum', 'yield_rf_visit_sum', 'interval_visit_mean'],
#       dtype='object')

# %% [markdown]
# # Yield

# %%
v = "sarea_udder"
u = "yield_visit_mean"
print(v+"_vs_"+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "area_udder"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "vol_udder"
u ="yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "peri_udder"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
# Out:
# sarea_udder_vs_yield_visit_mean
# PearsonRResult(statistic=0.4778734061956849, pvalue=8.952919127455261e-09)
#
#
# area_udder vs yield_visit_mean
# PearsonRResult(statistic=0.5498138985333649, pvalue=8.615523792929253e-12)
#
#
# vol_udder vs yield_visit_mean
# PearsonRResult(statistic=0.43660169104864377, pvalue=2.5762726634645955e-07)
#
#
# peri_udder vs yield_visit_mean
# PearsonRResult(statistic=0.5664984944730433, pvalue=1.4423345370999848e-12)

# %%
v = "sarea_udder"
u = 'interval_visit_mean'
print(v+"_vs_"+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "area_udder"
u = 'interval_visit_mean'
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "vol_udder"
u ='interval_visit_mean'
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "peri_udder"
u = 'interval_visit_mean'
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
# Out:
# sarea_udder_vs_interval_visit_mean
# PearsonRResult(statistic=-0.038815550592241385, pvalue=0.6610555490643465)
#
#
# area_udder vs interval_visit_mean
# PearsonRResult(statistic=-0.08594991177028835, pvalue=0.3271296312841365)
#
#
# vol_udder vs interval_visit_mean
# PearsonRResult(statistic=0.0754956385836957, pvalue=0.39701387231527235)
#
#
# peri_udder vs interval_visit_mean
# PearsonRResult(statistic=-0.08412962181633736, pvalue=0.3375163997282815)

# %%
merged = pd.read_csv(os.path.join("long_format_df", "visit_ft_long_udder.csv"))
merged.columns
# Out:
# Index(['cow', 'vol_udder', 'sarea_udder', 'peri_udder', 'area_udder',
#        'circ_udder', 'exc_udder', 'date', 'begin_time', 'days_in_milk',
#        'device_name', 'lactation_number', 'interval_sec', 'yield',
#        'is_incomplete', 'occ'],
#       dtype='object')

# %%
v = "sarea_udder"
u = 'interval_sec'
print(v+"_vs_"+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "area_udder"
u = 'interval_sec'
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "vol_udder"
u ='interval_sec'
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "peri_udder"
u = 'interval_sec'
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
# Out:
# sarea_udder_vs_interval_sec
# PearsonRResult(statistic=0.16007845879786972, pvalue=0.06886595362538298)
#
#
# area_udder vs interval_sec
# PearsonRResult(statistic=0.11899456615172598, pvalue=0.17415482788194767)
#
#
# vol_udder vs interval_sec
# PearsonRResult(statistic=0.24335059276669652, pvalue=0.005641412156026013)
#
#
# peri_udder vs interval_sec
# PearsonRResult(statistic=0.16377933634572828, pvalue=0.06058999354478744)

# %%
len(merged)
# Out:
# 138

# %%
fdf = pd.read_csv(os.path.join(data_path, 'myield_integrated.csv'))
ddf = pd.read_csv(features_path)
merged = ddf.merge(fdf, on = "cow", how= "left")

v = "udder_sarea"
u = "vyield_udder_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")

plt.ylabel("Average visit yield current lact. (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "front_eu"
u = "vyield_udder_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Front Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "back_eu"
u = "vyield_udder_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "lb_len"
u = "vyield_lb_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Left rear teat length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "rb_len"
u = "vyield_rb_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Right rear length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "rf_len"
u = "dyield_rf_dim_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Right rear length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
u = "vyield_udder_7d"
v = ['lf_angle', 'rf_angle', 'lb_angle', 'rb_angle']
merged["angle"]= merged[v[0]] + merged[v[1]] + merged[v[2]] + merged[v[3]]
selected = merged[[u, "angle"]].dropna(axis=0) 
res = stats.pearsonr(selected[u], selected["angle"])
plt.plot(selected[u], selected["angle"], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %% [markdown]
# # peak flow

# %%
fdf = pd.read_csv(os.path.join(data_path, 'mpf_integrated.csv'))
ddf = pd.read_csv(features_path)
merged = ddf.merge(fdf, on = "cow", how= "left")

# %%
v = "lb_len"
u = "peak_flow_lb_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "rb_len"
u = "peak_flow_rb_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "rf_exc"
u = "peak_flow_rf_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 v = "rf_exc"
#       2 u = "peak_flow_rf_7d"
# ----> 3 selected = merged[[v, u]].dropna(axis=0)
#       4 res = stats.pearsonr(selected[v], selected[u])
#       5 plt.plot(selected[v], selected[u], ".", color = "gray")
#
# NameError: name 'merged' is not defined

# %% [markdown]
# # Interval

# %%
dirpath = os.getcwd()
vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
merged = ddf.merge(vms_df, on ="cow", how= "left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dirpath = os.getcwd()
#       2 vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
#       3 vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
#
# NameError: name 'os' is not defined

# %%
from operator import mul

def time_tomin(my_time):
    factors = (60, 1, 1/60)
    t1 = sum(i*j for i, j in zip(map(int, my_time.split(':')), factors))
    t2 = sum(map(mul, map(int, my_time.split(':')), factors))
    return t2

# %%
v = "udder_vol"
u = "interval"
z = "lactation_number"
selected = merged[[v, u, z]].dropna(axis=0).reset_index()
selected[u] = [time_tomin(selected.loc[i, u]) for i in range(len(selected))] 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[u], selected[v],".", color = "gray")
plt.ylabel("Udder volume (L)")
plt.xlabel("Interval to last visit (min)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "udder_sarea"
u = "interval"
print(v+"_vs_"+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_area"
u = "interval"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_vol"
u = "interval"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_peri"
u = "interval"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "lf_peri"
u = "interval"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "rf_vol"
u = "interval"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)

# %%
u = "udder_sarea"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 u = "udder_sarea"
#       2 v = "lactation_number"
# ----> 3 selected = merged[[v, u ]].dropna(axis=0)
#       4 res = stats.pearsonr(selected[v], selected[u])
#       5 sns.boxplot(x = selected[v], y = selected[u])
#
# NameError: name 'merged' is not defined

# %%
u = "lb_len"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)
# Out:
# PearsonRResult(statistic=0.3944564973191206, pvalue=6.346249021084059e-06)

# %%
v = "udder_sarea"
u = "vyield_udder_7d"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(x,y, "*b")
print(res)
# Out:
# PearsonRResult(statistic=0.4483180884897785, pvalue=1.2528356824704467e-07)

# %%
dirpath = os.getcwd()
vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
merged = ddf.merge(vms_df, on ="cow", how= "left")

# %%
v = "udder_sarea"
u = "peak_yield"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(x,y, "*b")
print(res)
# Out:
# PearsonRResult(statistic=0.4130883475926361, pvalue=7.723219396997628e-05)

# %%
merged.columns
# Out:
# Index(['cow', 'udder_vol', 'lf_vol', 'rf_vol', 'lb_vol', 'rb_vol',
#        'udder_sarea', 'lf_sarea', 'rf_sarea', 'lb_sarea', 'rb_sarea',
#        'lf_angle', 'rf_angle', 'lb_angle', 'rb_angle', 'front_eu', 'back_eu',
#        'right_eu', 'left_eu', 'front_gd', 'back_gd', 'right_gd', 'left_gd',
#        'udder_peri', 'udder_area', 'udder_circ', 'udder_exc', 'lf_peri',
#        'lf_area', 'lf_circ', 'lf_exc', 'rf_peri', 'rf_area', 'rf_circ',
#        'rf_exc', 'lb_peri', 'lb_area', 'lb_circ', 'lb_exc', 'rb_peri',
#        'rb_area', 'rb_circ', 'rb_exc', 'lf_len', 'rf_len', 'lb_len', 'rb_len',
#        'farmname', 'robotside', 'filename', 'directory', 'date', 'time',
#        'size', 'computer', 'begin_time', 'end_time', 'yield', 'device_name',
#        'conductivity_lf', 'conductivity_lr', 'conductivity_rf',
#        'conductivity_rr', 'mean_flow_lf', 'mean_flow_lr', 'mean_flow_rf',
#        'mean_flow_rr', 'yield_lf', 'yield_lr', 'yield_rf', 'yield_rr',
#        'occ(*1000_cells/ml)', 'peak_flow_lf', 'peak_flow_lr', 'peak_flow_rf',
#        'peak_flow_rr', 'interval', 'quarters_num', 'num_videos', 'birth_date',
#        'age_in_days', 'last_calving_date', 'days_in_milk', 'lactation_number',
#        'total_kick-offs_last_7d', 'peak_occ_current_lactation',
#        'latest_lifetime_daily_yield', 'total_lifetime_yield', 'type',
#        'avg._occ_last_9_milkings', 'avg._flow_last_7_days',
#        'avg._yield_per_milking_last_7d', 'total_yield_in_lactation',
#        'peak_yield', 'peak_yield_day', 'peak_occ_current_lactation.1'],
#       dtype='object')
