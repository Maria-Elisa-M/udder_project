# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
plt.rcParams.update({'font.size': 14})

# %%
dirpath = os.getcwd()
features_path = r"C:\Users\marie\rep_codes\udder_project\udder_processing\features_dict\gmfeature_table.csv"
dirpath = os.getcwd()
data_path = os.path.join(dirpath, "..", "delpro_vms", "data")
# read vistit data
ddf = pd.read_csv(os.path.join(data_path, "merged2_videos_lactation.csv"))
fdf = pd.read_csv(features_path)
# plot_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),r"adsa\examples")

# %%
fdf.columns
# Out:
# Index(['cow', 'udder_vol', 'lf_vol', 'rf_vol', 'lb_vol', 'rb_vol',
#        'udder_sarea', 'lf_sarea', 'rf_sarea', 'lb_sarea', 'rb_sarea',
#        'lf_angle', 'rf_angle', 'lb_angle', 'rb_angle', 'front_eu', 'back_eu',
#        'right_eu', 'left_eu', 'front_gd', 'back_gd', 'right_gd', 'left_gd',
#        'udder_peri', 'udder_area', 'udder_circ', 'udder_exc', 'lf_peri',
#        'lf_area', 'lf_circ', 'lf_exc', 'rf_peri', 'rf_area', 'rf_circ',
#        'rf_exc', 'lb_peri', 'lb_area', 'lb_circ', 'lb_exc', 'rb_peri',
#        'rb_area', 'rb_circ', 'rb_exc', 'lf_len', 'rf_len', 'lb_len', 'rb_len'],
#       dtype='object')

# %% [markdown]
# # conductivity

# %%
# fdf = pd.read_csv(os.path.join(data_path, 'mcond_integrated.csv'))
# ddf = pd.read_csv(features_path)

# merged = ddf.merge(fdf, on = "cow", how= "left")
# v = "lb_vol"
# u = "conductivity_lf_7d"
# selected = merged[[v, u ]].dropna(axis=0) 
# selected =selected[selected[u] > 0]
# res = stats.pearsonr(selected[v], selected[u])
# plt.plot(selected[v], selected[u], "*b")
# print(res)

# %% [markdown]
# # Yield

# %%
merged = ddf.merge(fdf, on = "cow", how= "left")

# %%
v = "udder_sarea"
u = "yield_visit_mean"
print(v+"_vs_"+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_area"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_vol"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "udder_peri"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "lf_peri"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
print("\n")
v = "rf_vol"
u = "yield_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
v = "udder_vol"
u = "interval_visit_mean"
print(v+" vs "+ u)
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
print(res)
# Out:
# udder_sarea_vs_yield_visit_mean
# PearsonRResult(statistic=0.44602200111503865, pvalue=4.701231270632005e-08)
#
#
# udder_area vs yield_visit_mean
# PearsonRResult(statistic=0.5420808809277344, pvalue=5.506573758162723e-12)
#
#
# udder_vol vs yield_visit_mean
# PearsonRResult(statistic=0.46350820071560983, pvalue=1.5024601209366384e-08)
#
#
# udder_peri vs yield_visit_mean
# PearsonRResult(statistic=0.5576637205252131, pvalue=9.959653672359735e-13)
#
#
# lf_peri vs yield_visit_mean
# PearsonRResult(statistic=0.4338330029917493, pvalue=1.822097358581491e-07)
#
#
# rf_vol vs yield_visit_mean
# PearsonRResult(statistic=0.05776763313434935, pvalue=0.517181580413938)
# udder_vol vs interval_visit_mean
# PearsonRResult(statistic=0.14953764470737835, pvalue=0.08344089052964904)

# %%
v = "udder_sarea"
u = "yield_visit_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")

plt.ylabel("Average visit yield current lact. (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.44602200111503865, pvalue=4.701231270632005e-08)

# %%
v = "udder_vol"
u = "yield_visit_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "#BC1E40")
plt.xlabel("Udder volume (L)")
plt.ylabel("Average visit yield current lact. (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
plt.savefig( v+"_vs_"+ u+".png")
print(res)
# Out:
# PearsonRResult(statistic=0.46350820071560983, pvalue=1.5024601209366384e-08)

# %%
v = "front_eu"
u = "yield_lf_visit_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Front Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.15070560413448708, pvalue=0.08576005815388488)

# %%
v = "back_eu"
u = "yield_visit_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.20925484418435283, pvalue=0.017762564120513996)

# %%
v = "lb_len"
u = "yield_visit_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Left rear teat length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# PearsonRResult(statistic=0.3090238783826612, pvalue=0.00047910856662404234)

# %%
v = "rb_len"
u = "vyield_rb_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Right rear length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 v = "rb_len"
#       2 u = "vyield_rb_cl"
# ----> 3 selected = merged[[v, u]].dropna(axis=0)
#       4 res = stats.pearsonr(selected[v], selected[u])
#       5 plt.plot(selected[v], selected[u], ".", color = "gray")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['vyield_rb_cl'] not in index"

# %%
v = "rf_len"
u = "dyield_rf_dim_cl"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Right rear length (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
u = "vyield_udder_7d"
v = ['lf_angle', 'rf_angle', 'lb_angle', 'rb_angle']
merged["angle"]= merged[v[0]] + merged[v[1]] + merged[v[2]] + merged[v[3]]
selected = merged[[u, "angle"]].dropna(axis=0) 
res = stats.pearsonr(selected[u], selected["angle"])
plt.plot(selected[u], selected["angle"], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %% [markdown]
# # peak flow

# %%
fdf = pd.read_csv(os.path.join(data_path, 'mpf_integrated.csv'))
ddf = pd.read_csv(features_path)
merged = ddf.merge(fdf, on = "cow", how= "left")

# %%
v = "lb_len"
u = "peak_flow_lr_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "rb_len"
u = "peak_flow_rr_mean"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
v = "rf_exc"
u = "peak_flow_rf_7d"
selected = merged[[v, u]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[v], selected[u], ".", color = "gray")
plt.xlabel("Back Euclidean distance (cm)")
plt.ylabel("Average visit yield last 7d (L)")
plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %% [markdown]
# # Interval

# %%
vms_df = pd.read_csv(os.path.join(data_path, "milk_videos_visit.csv"))
merged = fdf.merge(vms_df, on ="cow", how= "left")

# %%
from datetime import date, datetime, timedelta
def interval_seconds(interval_str):
    if len(interval_str.split(" d ")) > 1:
        days = int(interval_str.split(" d ")[0])
        times = interval_str.split(" d ")[1].split(":")
    else:
        days = 0
        times = interval_str.split(" d ")[-1].split(":")
    hours = int(times[0])
    minutes = int(times[1])
    seconds = int(times[2])
    interval = timedelta(days = days, hours = hours, minutes = minutes, seconds = seconds).total_seconds()
    return interval

# %%
v = "udder_vol"
u = "interval_sec"
z = "lactation_number"

merged["interval_sec"] = [interval_seconds(rec) for rec in merged.interval]
selected = merged[[v, u, z]].dropna(axis=0).reset_index()
res = stats.pearsonr(selected[v], selected[u])
plt.plot(selected[u], selected[v],".", color = "gray")
plt.ylabel("Udder volume (L)")
plt.xlabel("Interval to last visit (min)")
# plt.savefig(os.path.join(plot_dir, v+"_vs_"+ u+".png"))
print(res)

# %%
u = "udder_sarea"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)

# %%
u = "udder_area"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)

# %%
u = "lb_len"
v = "lactation_number"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
sns.boxplot(x = selected[v], y = selected[u])
print(res)

# %%
v = "udder_sarea"
u = "vyield_udder_7d"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(x,y, "*b")
print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 v = "udder_sarea"
#       2 u = "vyield_udder_7d"
# ----> 3 selected = merged[[v, u ]].dropna(axis=0)
#       4 res = stats.pearsonr(selected[v], selected[u])
#       5 plt.plot(x,y, "*b")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['vyield_udder_7d'] not in index"

# %%
dirpath = os.getcwd()
vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
merged = ddf.merge(vms_df, on ="cow", how= "left")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 dirpath = os.getcwd()
#       2 vms_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir),"delpro_vms")
# ----> 3 vms_df = pd.read_csv(os.path.join(vms_dir, "milk_videos_filtered.csv"))
#       4 merged = ddf.merge(vms_df, on ="cow", how= "left")
#
# File ~\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\miniconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\marie\\rep_codes\\udder_project\\delpro_vms\\milk_videos_filtered.csv'

# %%
v = "udder_sarea"
u = "peak_yield"
selected = merged[[v, u ]].dropna(axis=0) 
res = stats.pearsonr(selected[v], selected[u])
plt.plot(x,y, "*b")
print(res)
# Out:
# PearsonRResult(statistic=0.4130883475926361, pvalue=7.723219396997628e-05)

# %%
merged.columns
# Out:
# Index(['cow', 'udder_vol', 'lf_vol', 'rf_vol', 'lb_vol', 'rb_vol',
#        'udder_sarea', 'lf_sarea', 'rf_sarea', 'lb_sarea', 'rb_sarea',
#        'lf_angle', 'rf_angle', 'lb_angle', 'rb_angle', 'front_eu', 'back_eu',
#        'right_eu', 'left_eu', 'front_gd', 'back_gd', 'right_gd', 'left_gd',
#        'udder_peri', 'udder_area', 'udder_circ', 'udder_exc', 'lf_peri',
#        'lf_area', 'lf_circ', 'lf_exc', 'rf_peri', 'rf_area', 'rf_circ',
#        'rf_exc', 'lb_peri', 'lb_area', 'lb_circ', 'lb_exc', 'rb_peri',
#        'rb_area', 'rb_circ', 'rb_exc', 'lf_len', 'rf_len', 'lb_len', 'rb_len',
#        'farmname', 'robotside', 'filename', 'directory', 'date', 'time',
#        'size', 'computer', 'begin_time', 'end_time', 'yield', 'device_name',
#        'conductivity_lf', 'conductivity_lr', 'conductivity_rf',
#        'conductivity_rr', 'mean_flow_lf', 'mean_flow_lr', 'mean_flow_rf',
#        'mean_flow_rr', 'yield_lf', 'yield_lr', 'yield_rf', 'yield_rr',
#        'occ(*1000_cells/ml)', 'peak_flow_lf', 'peak_flow_lr', 'peak_flow_rf',
#        'peak_flow_rr', 'interval', 'quarters_num', 'num_videos', 'birth_date',
#        'age_in_days', 'last_calving_date', 'days_in_milk', 'lactation_number',
#        'total_kick-offs_last_7d', 'peak_occ_current_lactation',
#        'latest_lifetime_daily_yield', 'total_lifetime_yield', 'type',
#        'avg._occ_last_9_milkings', 'avg._flow_last_7_days',
#        'avg._yield_per_milking_last_7d', 'total_yield_in_lactation',
#        'peak_yield', 'peak_yield_day', 'peak_occ_current_lactation.1'],
#       dtype='object')
