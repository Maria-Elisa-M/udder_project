# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import date, datetime, timedelta
from sklearn import linear_model
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_8320\3028730387.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dirpath = os.getcwd()
data_path = os.path.join(dirpath, "..", "delpro_vms", "data")
feature_path = os.path.join(dirpath, "..", "udder_processing", "features_dict")
out_dir = "long_format_df"
# read vistit data
data_df = pd.read_csv(os.path.join(data_path, "merged_lactation.csv"))
# read features
feature_df = pd.read_csv(os.path.join(feature_path, "gmfeature_table.csv"))
feature_df = feature_df.rename(columns = lambda col: "_".join(col.split("_")[::-1]) if "_" in col else col)

# %%
merged_long = pd.merge(feature_df, data_df, left_on = ["cow"], right_on = ["animal_number"])
merged_long.to_csv(os.path.join(out_dir, "lactation_features.csv"), index = False)

# %%
merged_long
# Out:
#       cow  vol_udder    vol_lf    vol_rf    vol_lb    vol_rb  sarea_udder  \
# 0     627   6.742235  2.085106  2.320265  0.655287  0.907118  2202.840957
# 1     723   5.866114  3.189081  1.988038  0.497105  0.565673  1557.547077
# 2     729        NaN  5.068295  4.355240  0.786221  0.891771          NaN
# 3     736   8.529069  5.034365  1.684315  1.298735  0.676856  2190.923732
# 4     764   6.316109  1.788540  2.241100  0.752663  0.685146          NaN
# ..    ...        ...       ...       ...       ...       ...          ...
# 133  1486   5.378144  1.734115  1.861548  0.768159  0.702433  1964.898450
# 134  1487   8.376260  5.059448  3.538225  0.712471  0.503287  1788.671257
# 135  1495   5.783034  1.668636  3.162655  0.557299  0.537761  1910.238056
# 136  1501   7.486284  2.142604  4.278479  0.523835  0.720675  1688.992494
# 137  1504   5.590657  1.046042  2.229637  0.923492  1.236515  2040.123938
#
#         sarea_lf    sarea_rf    sarea_lb  ...  kickoff_rf_perc  \
# 0     676.526869  710.606157  388.758950  ...         0.000000
# 1     620.012292  569.962040  259.224542  ...         0.000000
# 2            NaN  998.056447  255.710493  ...         0.111607
# 3    1036.329523  415.856293  525.530135  ...         0.374532
# 4     825.074567  901.399146  567.414139  ...         0.409277
# ..           ...         ...         ...  ...              ...
# 133   521.314016  589.685346  475.684154  ...         1.754386
# 134   869.119892  720.359164  208.901041  ...         0.000000
# 135   434.406296  775.294209  346.581440  ...         2.173913
# 136   433.107657  923.958614  210.824871  ...        30.232558
# 137   385.794117  606.989457  438.238827  ...         0.273973
#
#      kickoff_rr_perc  kickoff_front_perc  kickoff_back_perc  kickoff_any_perc  \
# 0           0.000000            0.000000           0.000000          0.000000
# 1           0.000000            0.000000           0.000000          0.000000
# 2           1.004464            0.781250           2.343750          2.343750
# 3           0.499376            0.873908           1.373283          1.747815
# 4           0.136426            1.091405           0.545703          0.954980
# ..               ...                 ...                ...               ...
# 133         1.754386            1.754386           3.508772          4.093567
# 134         0.508906            0.890585           0.636132          0.636132
# 135         4.347826            2.173913           4.347826          4.347826
# 136        51.162791           44.186047          62.790698         62.790698
# 137         0.410959            0.410959           0.547945          0.821918
#
#      yield_lf_visit_sum  yield_lr_visit_sum  yield_rr_visit_sum  \
# 0                948.77             1347.54             1480.53
# 1                346.00              369.72              287.01
# 2               4776.20             4548.33             4953.81
# 3               2524.63             3707.99             4089.27
# 4               3760.88             4127.59             1047.17
# ..                  ...                 ...                 ...
# 133              457.27              488.74              430.47
# 134             2633.47             3487.49             3339.83
# 135              125.65              111.28              113.77
# 136              134.60              146.79              132.51
# 137             1993.32             2526.68             2512.82
#
#      yield_rf_visit_sum  interval_visit_mean
# 0               1065.06         31442.340000
# 1                276.32         36978.048780
# 2               5725.95         36087.228795
# 3               2908.86         34144.249688
# 4               3398.21         33631.328786
# ..                  ...                  ...
# 133              460.56         31781.508772
# 134             2627.71         32828.129771
# 135              134.00         39553.326087
# 136              142.79         41876.093023
# 137             2507.76         33584.263014
#
# [138 rows x 85 columns]
