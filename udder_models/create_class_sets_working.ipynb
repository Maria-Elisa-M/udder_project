# %%
import os 
import pandas as pd
import shutil

# class sest df
sets_df = pd.read_csv("frameclass_sets.csv")

# directories
dirpath = os.getcwd()
img_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir), r'udder_video\depth_images')
old_dir = os.path.join(os.path.normpath(dirpath + os.sep + os.pardir), r'udder_dcc\images')
data_dir = os.path.join(dirpath, r"frame_classify\data")
# data collection groups
imgdir_dict = {20210625:{"lab": old_dir}, \
              20211022: {"lab": old_dir}, \
              20231117:{"guilherme": img_dir , \
                        "maria": img_dir}}

clas_dict = {0:"bad", 1:"good"}

def mk_dest_dir(data_dir , file_set, file_class):
    if not os.path.exists(data_dir):
        os.mkdir(data_dir)
    set_dir = os.path.join(data_dir, file_set)
    if not os.path.exists(set_dir):
        os.mkdir(set_dir)
    class_dir = os.path.join(set_dir, file_class)
    if not os.path.exists(class_dir):
        os.mkdir(class_dir)

for file in sets_df.filename[:50]:
    file_name = file + ".tif"
    file_line = sets_df[sets_df.filename == file]
    # find source directory
    file_date = file_line["date"].values[0]
    computer  = file_line["computer"].values[0]
    src_dir = imgdir_dict[file_date][computer]
    img_dir = os.path.join(src_dir, file_name)
    print(img_dir)
    # find/create dest directoy
    file_set = file_line["set_name"].values[0]
    file_class = clas_dict[file_line["frame_class"].values[0]]
    mk_dest_dir(data_dir , file_set, file_class)
    dest_dir = os.path.join(data_dir , file_set, file_class)
    print(dest_dir)
    # copy image
    # shutil.copy(img_dir, dest_dir)
# Out:
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_435.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_355.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_314.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_270.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_403.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_400.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_341.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_282.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_240.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_336.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_277.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_323.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_379.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_439.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_289.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_346.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_352.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_291.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_356.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_423.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_243.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_369.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_193.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_306.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_354.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_387.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_364.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_276.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_262.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_414.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_413.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_190.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_373.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_248.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_363.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_235.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_340.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_405.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_229.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_437.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_436.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_215.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_247.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_242.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_204.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_224.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_212.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_208.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_213.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
# C:\Users\marie\rep_codes\udder_project\udder_dcc\images\20210625_125_under_233.tif
# C:\Users\marie\rep_codes\udder_project\udder_models\frame_classify\data\test\bad
